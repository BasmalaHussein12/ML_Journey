# %%
# Pandas Basics
In this notebook, I learn the fundamentals of Pandas, one of the most popular Python libraries for data analysis.

## Topics
- What is Pandas?
- Series
- DataFrame
- Creating Series
- Creating DataFrames
- Basic Attributes

# %%
For importing pandas:

import pandas as pd

# %%
# Pandas
is a Python library used for data manipulation and analysis

It provides two main data structures:

- Series (one-dimensional)
- DataFrame (two-dimensional)

# %%
# Series
A Series is a one-dimensional labeled array

# %%
import pandas as pd 

numbers = pd.Series([10,20,30,40,50])
numbers
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# Access Elements 
as we used to

# %%
import pandas as pd 

numbers = pd.Series([10,20,30,40,50])
numbers[3]
# Out:
# np.int64(40)

# %%
# series attributes
numbers.shape --> (rows, columns)
numbers.size --> number of elements 
numbers.dtype --> type of the data

# %%
import pandas as pd 

numbers = pd.Series([10,20,30,40,50])
numbers.shape
# Out:
# (5,)

# %%
import pandas as pd 

numbers = pd.Series([10,20,30,40,50])
numbers.size
# Out:
# 5

# %%
import pandas as pd 

numbers = pd.Series([10,20,30,40,50])
numbers.dtype
# Out:
# dtype('int64')

# %%
# Creating a DataFrame
A DataFrame is a two-dimensional table with rows and columns.

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)

df
# Out:
#    Name  Age  Grade
# 0   Ali   20     90
# 1  Sara   21     85
# 2  Omar   19     95

# %%
import pandas as pd

coutries = {
    "Name": ["Italy", "Egypt", "USA"],
    "Captilal": ["Roma", "Cairo", "Washington"]
}

x = pd.DataFrame(coutries)
x
# Out:
#     Name    Captilal
# 0  Italy        Roma
# 1  Egypt       Cairo
# 2    USA  Washington

# %%
# DataFrame Attributes

df.shape
df.size
df.columns
df.index
df.dtypes

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)
df.shape
# Out:
# (3, 3)

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)
df.size
# Out:
# 9

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)
df.columns
# Out:
# Index(['Name', 'Age', 'Grade'], dtype='object')

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)
df.dtypes
# Out:
# Name     object
# Age       int64
# Grade     int64
# dtype: object

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)
df["Name"]
# Out:
# 0     Ali
# 1    Sara
# 2    Omar
# Name: Name, dtype: object

# %%
students = {
    "Name": ["Ali", "Sara", "Omar"],
    "Age": [20, 21, 19],
    "Grade": [90, 85, 95]
}

df = pd.DataFrame(students)
df[["Name", "Grade"]]
# Out:
#    Name  Grade
# 0   Ali     90
# 1  Sara     85
# 2  Omar     95

# %%
# Creating a DataFrame from Lists
import pandas as pd

names = ["Basmala", "Sara", "MO"]
grades = [90, 80, 65]
ages = [19, 20, 18]

df = pd.DataFrame ({
    "Names": names,
    "Grades": grades,
    "Ages": ages,
})

df
# Out:
#      Names  Grades  Ages
# 0  Basmala      90    19
# 1     Sara      80    20
# 2       MO      65    18

# %%
## Summary

In this notebook, I learned:

- What Pandas is
- What a Series is
- What a DataFrame is
- How to create a Series
- How to create a DataFrame
- DataFrame attributes
- Selecting columns
