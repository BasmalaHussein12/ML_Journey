# %% [markdown]
# # Feature Selection
#
# Feature selection is the process of choosing only the most useful features from the dataset for a machine learning model.
#
# The main idea is simple:
#
# > We have many features, but not all of them are useful for prediction.
#
# Feature selection helps us remove irrelevant or redundant features.
#
# ### Why do we use Feature Selection?
#
# - Remove irrelevant features
# - Reduce noise
# - Reduce model complexity
# - Make training faster
# - Improve interpretability
# - Reduce the risk of overfitting
# - Help the model focus on useful information
#
# ### Simple Example
#
# Suppose we want to predict whether a person will buy a product:
#
# | Age | Salary | Height | Hours_Studied | Bought |
# |---|---:|---:|---:|---|
# | 20 | 5000 | 170 | 5 | Yes |
# | 25 | 7000 | 180 | 2 | No |
# | 22 | 6000 | 165 | 6 | Yes |
#
# Features:
#
# - Age
# - Salary
# - Height
# - Hours_Studied
#
# Target:
#
# - Bought
#
# If `Height` has almost no relationship with `Bought`, we may remove it.
#
# So instead of:
#
# Age + Salary + Height + Hours_Studied
#
# we may use:
#
# Age + Salary + Hours_Studied
#
# This is Feature Selection.
#
# ---
#
# # Feature Selection vs Feature Extraction
#
# These two concepts are related but different.
#
# ### Feature Selection
#
# We **choose existing features**.
#
# ```text
# Age
# Salary
# Height
# Experience
#        ↓
# Select
#        ↓
# Age
# Salary
# Experience

# %% [markdown]
# # Chi-Square
#
# Used to check relationships between categorical variables.

# %% [markdown]
# # Pearson Correlation
#
# Measures a linear relationship between continuous variables.

# %% [markdown]
# # Variance Threshold
#
#    ## Very simple idea:
#
# If a feature barely changes:
#
# Age:
#
# 20
#
# 20
#
# 20
#
# 20
#
# 20
#
# it probably doesn't give the model much useful information.
#
# So we can remove it.

# %% [markdown]
#                  FEATURE SELECTION
#                         │
#           ┌─────────────┼─────────────┐
#           ↓             ↓             ↓
#        FILTER        WRAPPER       EMBEDDED
#           │             │             │
#      Statistics      Try subsets    During training
#           │             │             │
#      No model       Uses model       Model itself
#           │             │             │
#      Fast           Expensive       Efficient
#           │
#    ┌──────┼───────────────┐
#    ↓      ↓       ↓       ↓
#  Info    Chi²    Pearson   Variance
#  Gain

# %% [markdown]
# Filter:
#   → Correlation
#   → Chi-square
#   → Variance Threshold
#
# Wrapper:
#   → Forward Selection
#   → Backward Elimination
#   → RFE
#
# Embedded:
#   → Lasso (L1)
#   → Decision Trees
#   → Random Forest

# %% [markdown]
# # What I Need to Remember
#
# I do not need to memorize every feature selection technique at this stage.
#
# I mainly need to understand the three ideas:
#
# 1. Filter → statistical selection
# 2. Wrapper → try feature subsets using a model
# 3. Embedded → feature selection happens during model training
#
# The most important concept is:
#
# > Feature Selection chooses the most useful existing features instead of creating new ones.
