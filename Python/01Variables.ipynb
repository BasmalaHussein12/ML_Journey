# %%
# Variables and data type
In this notebook, I will learn how to create variables and work with basics python data types

# %%
name = "Basmala" 
age = 19 
gpa = 3.33
Is_learning_python = True

# %%
print(name)
print(age)
print(gpa)
print(Is_learning_python)
# Out:
# Basmala
# 19
# 3.33
# True

# %%
# Now, I will check the data types

# %%
print(type(name))
print(type(age))
print(type(gpa))
print(type(Is_learning_python))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Variable naming rules
- A variable cannot start with a number 
1name = "basmala" --wrong 

name1 = "basmala" --correct
##################################
- No space allowed 
first name = "basmala" --wrong 

first_name = "basmala" --correct
##################################
- Python is case-sensitive
age = 19 
Age = 20

print(age) //19
print(Age)//20
#################################
- Avoid using python reserved words 
{if, else, for, while, class, def, return, import, ...}

# %%
# Type conversion or casting 

Look at the next example:

# %%
age = input("Enter your age:")
print(type(age))
# Out:
# Enter your age: 19
# <class 'str'>

# %%
# It returns 'str', because Python always sees input() as a string

Now, I will convert it into integar

# %%
age = input("Enter your age:")
age = int(age)
print(type(age))
# Out:
# Enter your age: 19
# <class 'int'>

# %%
# Converting from int to string
In the next example, I want to print a message that contains my name and my age

# %%
age = 19     
name = "basmala"
message = f"I am {name} and I am {str(age)} years old"
print(message)
# Out:
# I am basmala and I am 19 years old

# %%
# converting into float

# %%
x = 10 
y = float(x)
print(y)
# Out:
# 10.0

# %%
# To sum up 
These are the methods to convert a data type to another:
- int()
- float()
- str()
- bool()

# %%
# Multiple Assignment 
Python allows us to assign values to multiple variables in one line

# %%
name, age, country = "basmala", 19, "Egypt"
print(name)
print(age)
print(country)
# Out:
# basmala
# 19
# Egypt

# %%
# Also, we can assign multiple variables to the same value

# %%
x = y = z = 0
print(x)
print(y)
print(z)
# Out:
# 0
# 0
# 0

# %%
# Constants--> are values that should remain unchanged
Python uses uppercase names as a conversion

# %%
PI = 3.14159
print(PI)
# Out:
# 3.14159

# %%
# How python stores variables ?
By:
- lists
- NumPy arrays
- Pandas DataFrames
- Machine learning data

### Variables are references, not boxes 
age = 19 
age --------------> object containing 19

The variable name points to an object in memory

# %%
# If I want to know where my variable stored 
by -----> id()

# %%
age = 19
print(id(age))
# Out:
# 140723048068584

# %%
# The number in the previous cell is the object's identity (memory address in CPython)

# %%
# We can have 2 variables refer to the same object 
Look in the next example

# %%
x = 10
y = 10

print (x)
print(y)
# Out:
# 10
# 10

# %%
# We can reassignment the variable

x = 10
y = 10
x = 20

print(x)
print(y)
# Out:
# 20
# 10
