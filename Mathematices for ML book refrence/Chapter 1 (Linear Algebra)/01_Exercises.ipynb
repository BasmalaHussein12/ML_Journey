# %%
students = np.array([
    [170,65,20],
    [180,72,22],
    [165,55,19]
])

# %% [markdown]
# <!-- Answer: -->
#
# 1) What does each row represent?
# it representes a record
#
# 2) What does each column represent?
# it representes a columns
#
# 3) What is the size of the matrix?
# 3 rows * 3 columns
#
# 4) Transpose the matrix.
# in the next cell
#
# 5) Explain in words what the transposed matrix represents.
# The transposed matrix reorganizes the data so that each row represents one feature instead of one student

# %%
import numpy as np

students = np.array([
    [170,65,20],
    [180,72,22],
    [165,55,19]
])

students. T
# Out:
# array([[170, 180, 165],
#        [ 65,  72,  55],
#        [ 20,  22,  19]])
