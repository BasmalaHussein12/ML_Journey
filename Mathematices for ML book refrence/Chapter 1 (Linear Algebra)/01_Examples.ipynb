# %%
import numpy as np

x = np.array([1,2,3])

print(x)
# creating vectors
# Out:
# [1 2 3]

# %%
A = np.array([
    [1,2],
    [3,4]
])

print(A)
# creating matrix
# Out:
# [[1 2]
#  [3 4]]

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])

A + B
# matrix addition
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])

A @ B
# matrix multiplication
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])

np.matmul(A,B)
# another way to multiplication
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])

np.eye(3)
# identify matrix
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
A = np.array([
    [1,2],
    [3,4]])

A. T
# matrix tranpose
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
A = np.array([
    [1,2],
    [3,4]])

np.linalg.inv(A)
# matrix inverse
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
A = np.array([
    [2,1],
    [1,3]
])

b = np.array([5,7])

x = np.linalg.solve(A,b)

print(x)
# solving XA = B
# Out:
# [1.6 1.8]
