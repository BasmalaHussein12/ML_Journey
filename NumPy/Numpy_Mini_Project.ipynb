# %%
# Mini Project: Student Grades Analysis Using NumPy

<____Project Description:____>

You are a data analyst at a school. The administration has provided the grades of students from two exams. 
Your task is to analyze the data and generate a comprehensive report using NumPy.
The report should help the school understand students' performance by calculating statistics, filtering data, reshaping arrays, and comparing exam results.

<<Requirements>>

---Data Creation---
Create the grades of 12 students for the first exam using a NumPy function (avoid typing every number manually).
Create another array for the second exam.
              
---Data Exploration---
Analyze the first exam by displaying:
              
Shape
Number of dimensions
Number of elements
Data type

---Data Transformation---
Reshape the first exam into a 3 × 4 matrix representing 3 classrooms with 4 students each.
Display the transpose of the matrix.
Flatten the matrix.
Use ravel().
    
---Student Analysis---
Find and display:
Highest grade
Lowest grade
Average grade
Total grades
Standard deviation
Also calculate:
Average grade for each classroom.
Average grade for each student position.
    
---Indexing & Slicing---
Display:
    
First classroom.
Last classroom.
First student in each classroom.
Last student in each classroom.
The student located in the second classroom and third seat.
Every second student.
Reverse the students' order.

---Performance Filtering---
Display:

Students scoring above 75.
Students scoring below 65.
Even grades.
Grades divisible by 5.
    
---Grade Adjustment---
The school decides to apply new grading rules.
Create new arrays that:
    
Add 5 bonus marks.
Deduct 2 marks.
Increase all grades by 10%.
Calculate the square root of every grade.

---Comparing Exams---
Using the two exam arrays:
    
Concatenate them.
Stack them vertically.
Stack them horizontally.
    
---Splitting Data---
Split the first exam grades into:
    
Two equal groups.
Three equal groups.

---Duplicate Detection---
Create another array containing repeated grades.
Display only the unique grades using NumPy.

# %%
import numpy as np

exam1 = np.arange(60,96,3)
exam2 = np.arange(60,96,3)

shape = exam1.shape
number_of_diems = exam1.ndim
number_of_students = exam1.size
type_of_data = exam1.dtype

high1 = np.max(exam1)
low1 = np.min(exam1)
average1 = np.mean(exam1)
standard_division = np.std(exam1)
total = np.sum(exam1)





print('='*50)
print("      ___Student Grades Analysis Report___")
print('='*50)
print()

print("Exam Information:")
print('-'*20)

print(f"Shape: {shape}")
print(f"Dimensions: {number_of_diems}")
print(f"Size: {number_of_students}")
print(f"Data type: {type_of_data}")

print()

print("Statistical:")
print('-'*20)

print(f"Highest Grade: {high1}")
print(f"Lowest Grade: {low1} ")
print(f"Average Grade: {average1} ")
print(f"Standard Divesions: {standard_division} ")
print(f"Total Grades: {total} ")

print()
print()

print("Top students (>75):")
high_grades = (exam1[exam1 > 75])
if high_grades.size > 0:
   print(high_grades)

print()    

print("Students belows 65:")
low_grades = (exam1[exam1 < 65])
if low_grades.size > 0:
   print(low_grades)

print()

print("Even Grades: ")
even_grades = (exam1[exam1 % 2 == 0])
if even_grades.size > 0 :
   print(even_grades)

print()

print("Grades Divisible by 5: ")
divisible_grades = (exam1[exam1 % 2 == 0])
if even_grades.size > 0 :
   print(even_grades)
# Out:
# ...
#       ___Student Grades Analysis Report___
# ...
#
# Exam Information:
# --------------------
# Shape: (12,)
# Dimensions: 1
# Size: 12
# Data type: int64
#
# Statistical:
# --------------------
# Highest Grade: 93
# Lowest Grade: 60
# Average Grade: 76.5
# Standard Divesions: 10.35615758860399
# Total Grades: 918
#
#
# Top students (>75):
# [78 81 84 87 90 93]
#
# Students belows 65:
# [60 63]
#
# Even Grades:
# [60 66 72 78 84 90]
